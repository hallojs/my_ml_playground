# %% [markdown]
# # Input Generator Keras Model

# %% [markdown]
# In this notebook I experiment how to use generators as input for a keras model. The data and the model don't make sense, I only want to understand how python generators can be used to train a TensorFlow Keras model.

# %%
import random
import numpy as np

def generator(data, batch_size):
    cnt = 0
    batches = int(len(data) / batch_size)
    while 1:
        batch = data[cnt*batches:cnt+1*batches]
        cnt += 1
        yield (batch, batch)
        # reset counter for next epoch
        if cnt >= batches:
            cnt = 0

# %%
# Model Architecture
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Activation

# number of features
input_dim = 8
hidden_dim = int(input_dim / 2)

model = Sequential()
# encoder
model.add(Dense(input_dim))
model.add(Activation('tanh'))
model.add(Dense(hidden_dim))
model.add(Activation('relu'))

# decoder
model.add(Dense(hidden_dim))
model.add(Activation('relu'))
model.add(Dense(input_dim))
model.add(Activation('tanh'))

# %%
data = np.random.rand(10000, 8)
X = generator(data, 50)

# number of times model is trained over whole the dataset
epochs = 10

# is used to generate the entire dataset once by calling the generator
# steps_per_epoch times; samples = steps_per_epoch * batches
steps_per_epoch = 200

model.compile(optimizer='adam',
              loss='mean_squared_error',
              metrics=['accuracy'])

model.fit(X,
          epochs=epochs,
          verbose=1,
          steps_per_epoch=steps_per_epoch)
# Out:
# Epoch 1/10
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3922 - accuracy: 0.1343
# Epoch 2/10
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3683 - accuracy: 0.1343
# Epoch 3/10
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3355 - accuracy: 0.1343
# Epoch 4/10
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3088 - accuracy: 0.1294
# Epoch 5/10
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2848 - accuracy: 0.0995
# Epoch 6/10
# 200/200 [==============================] - 1s 3ms/step - loss: 0.2307 - accuracy: 0.0846
# Epoch 7/10
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1731 - accuracy: 0.1244
# Epoch 8/10
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1495 - accuracy: 0.1294
# Epoch 9/10
# 200/200 [==============================] - 1s 3ms/step - loss: 0.1379 - accuracy: 0.1294
# Epoch 10/10
# 200/200 [==============================] - 1s 4ms/step - loss: 0.1284 - accuracy: 0.1294
